# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (3.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from transformers) (2020.7.14)
# Requirement already satisfied: sentencepiece!=0.1.92 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from transformers) (0.1.91)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from transformers) (0.6)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from transformers) (20.3)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from transformers) (2.23.0)
# Requirement already satisfied: sacremoses in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from transformers) (0.0.43)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: tokenizers==0.8.1.rc1 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from transformers) (0.8.1rc1)
# Requirement already satisfied: tqdm>=4.27 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from transformers) (4.44.1)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from transformers) (1.18.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from packaging->transformers) (2.4.6)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from packaging->transformers) (1.14.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from requests->transformers) (2020.4.5.2)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from requests->transformers) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from requests->transformers) (1.25.8)
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from sacremoses->transformers) (0.14.1)
# Requirement already satisfied: click in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from sacremoses->transformers) (7.1.1)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_latest_p36/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install sklearn_crfsuite
# Out:
# Requirement already satisfied: sklearn_crfsuite in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (0.3.6)
# Requirement already satisfied: tabulate in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from sklearn_crfsuite) (0.8.7)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from sklearn_crfsuite) (0.9.7)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from sklearn_crfsuite) (1.14.0)
# Requirement already satisfied: tqdm>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (from sklearn_crfsuite) (4.44.1)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_latest_p36/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ### Set the Parameters

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils import data
import os
import numpy as np
from collections import OrderedDict
from sklearn.metrics import classification_report
from sklearn_crfsuite.utils import flatten

from transformers import AutoTokenizer, AutoModelWithLMHead, AutoModel

# %%
import os
os.getcwd()
# Out:
# '/home/ec2-user/SageMaker/BIO_NER'

# %% [markdown]
# #### Load the data

# %%
import numpy as np 
from torch.utils import data 
import torch 



class HParams:
    def __init__(self, vocab_type):
        self.VOCAB_DICT = {
            'bc5cdr': ('<PAD>', 'B-Chemical', 'O', 'B-Disease' , 'I-Disease', 'I-Chemical'),
            'bionlp3g' : ('<PAD>', 'B-Amino_acid', 'B-Anatomical_system', 'B-Cancer', 'B-Cell', 
                        'B-Cellular_component', 'B-Developing_anatomical_structure', 'B-Gene_or_gene_product', 
                        'B-Immaterial_anatomical_entity', 'B-Multi-tissue_structure', 'B-Organ', 'B-Organism', 
                        'B-Organism_subdivision', 'B-Organism_substance', 'B-Pathological_formation', 
                        'B-Simple_chemical', 'B-Tissue', 'I-Amino_acid', 'I-Anatomical_system', 'I-Cancer', 
                        'I-Cell', 'I-Cellular_component', 'I-Developing_anatomical_structure', 'I-Gene_or_gene_product', 
                        'I-Immaterial_anatomical_entity', 'I-Multi-tissue_structure', 'I-Organ', 'I-Organism', 
                        'I-Organism_subdivision', 'I-Organism_substance', 'I-Pathological_formation', 'I-Simple_chemical', 
                        'I-Tissue', 'O')
        }
        self.VOCAB = self.VOCAB_DICT[vocab_type]
        self.tag2idx = {v:k for k,v in enumerate(self.VOCAB)}
        self.idx2tag = {k:v for k,v in enumerate(self.VOCAB)}

        self.batch_size = 128 
        self.lr = 0.0001
        self.n_epochs = 30 

        #self.tokenizer = BertTokenizer(vocab_file=VOCAB_FILE, do_lower_case=False)
        self.tokenizer = AutoTokenizer.from_pretrained("monologg/biobert_v1.0_pubmed_pmc")
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'


class NerDataset(data.Dataset):
    def __init__(self, path, vocab_type):
        self.hp = HParams(vocab_type)
        instances = open(path).read().strip().split('\n\n')
        sents = []
        tags_li = []
        for entry in instances:
            words = [line.split()[0] for line in entry.splitlines()]
            tags = ([line.split()[-1] for line in entry.splitlines()])
            sents.append(["[CLS]"] + words + ["[SEP]"])
            tags_li.append(["<PAD>"] + tags + ["<PAD>"])
        self.sents, self.tags_li = sents, tags_li

    def __len__(self):
        return len(self.sents)


    def __getitem__(self, idx):
        words, tags = self.sents[idx], self.tags_li[idx] # words, tags: string list

        # We give credits only to the first piece.
        x, y = [], [] # list of ids
        is_heads = [] # list. 1: the token is the first piece of a word
        for w, t in zip(words, tags):
            tokens = self.hp.tokenizer.tokenize(w) if w not in ("[CLS]", "[SEP]") else [w]
            xx = self.hp.tokenizer.convert_tokens_to_ids(tokens)

            is_head = [1] + [0]*(len(tokens) - 1)

            t = [t] + ["<PAD>"] * (len(tokens) - 1)  # <PAD>: no decision
            yy = [self.hp.tag2idx[each] for each in t]  # (T,)

            x.extend(xx)
            is_heads.extend(is_head)
            y.extend(yy)

        assert len(x)==len(y)==len(is_heads), f"len(x)={len(x)}, len(y)={len(y)}, len(is_heads)={len(is_heads)}"

        # seqlen
        seqlen = len(y)

        # to string
        words = " ".join(words)
        tags = " ".join(tags)
        return words, x, is_heads, tags, y, seqlen


def pad(batch):
    '''Pads to the longest sample'''
    f = lambda x: [sample[x] for sample in batch]
    words = f(0)
    is_heads = f(2)
    tags = f(3)
    seqlens = f(-1)
    maxlen = np.array(seqlens).max()

    f = lambda x, seqlen: [sample[x] + [0] * (seqlen - len(sample[x])) for sample in batch] # 0: <pad>
    x = f(1, maxlen)
    y = f(-2, maxlen)


    f = torch.LongTensor

    return words, f(x), is_heads, tags, f(y), seqlens

# %% [markdown]
# #### Define the Model

# %%
import torch
import torch.nn as nn

class Net(nn.Module):
    def __init__(self, vocab_len, device = 'cpu'):
        super().__init__()
        self.bert = AutoModel.from_pretrained("monologg/biobert_v1.0_pubmed_pmc")
        self.bert.eval()
        self.rnn = nn.LSTM(bidirectional=True, num_layers=2, input_size=768, hidden_size=768//2, batch_first=True)
        self.fc = nn.Linear(768, vocab_len)
        self.device = device

    def forward(self, x, y):
        '''
        x: (N, T). int64
        y: (N, T). int64

        Returns
        enc: (N, T, VOCAB)
        '''
        x = x.to(self.device)
        y = y.to(self.device)
        #print(x.shape)
        #print(y.shape)

        with torch.no_grad():
            encoded_layers, _ = self.bert(x)
            #print(encoded_layers.shape)
            #enc = encoded_layers[-1]
            #print(enc.shape)
        enc, _ = self.rnn(encoded_layers)
        #print(enc.shape)
        logits = self.fc(enc)
        y_hat = logits.argmax(-1)
        return logits, y, y_hat

# %% [markdown]
# ### Train the model

# %%
### Train the model
def train(model, iterator, optimizer, criterion):
    model.train()
    for i, batch in enumerate(iterator):
        words, x, is_heads, tags, y, seqlens = batch
        _y = y # for monitoring
        optimizer.zero_grad()
        logits, y, _ = model(x, y) # logits: (N, T, VOCAB), y: (N, T)

        logits = logits.view(-1, logits.shape[-1]) # (N*T, VOCAB)
        y = y.view(-1)  # (N*T,)

        loss = criterion(logits, y)
        loss.backward()

        optimizer.step()

        if i==0:
            print("=====sanity check======")
            #print("x:", x.cpu().numpy()[0])
            print("words:", words[0])
            print("\n")
            #print("tokens:", hp.tokenizer.convert_ids_to_tokens(x.cpu().numpy()[0]))
            #print("y:", _y.cpu().numpy()[0])
            #print("is_heads:", is_heads[0])
            print("tags:", tags[0])
            print("\n")
            #print("seqlen:", seqlens[0])


        if i%10==0: # monitoring
            print(f"step: {i}, loss: {loss.item()}")

def eval(model, iterator, f):
    model.eval()

    Words, Is_heads, Tags, Y, Y_hat = [], [], [], [], []
    with torch.no_grad():
        for i, batch in enumerate(iterator):
            words, x, is_heads, tags, y, seqlens = batch

            _, _, y_hat = model(x, y)  # y_hat: (N, T)

            Words.extend(words)
            Is_heads.extend(is_heads)
            Tags.extend(tags)
            Y.extend(y.numpy().tolist())
            Y_hat.extend(y_hat.cpu().numpy().tolist())

    
    y_pred =[]
    y_true = []
    for words, is_heads, tags, y_hat, y in zip(Words, Is_heads, Tags, Y_hat, Y):
            y_hat = [hat for head, hat in zip(is_heads, y_hat) if head == 1]
            y_pred.append(y_hat[1:-1])
            y = [hat for head, hat in zip(is_heads, y) if head == 1]
            y_true.append(y[1:-1])
            assert len(y_pred)==len(y_true), f"len(y_pred)={len(y_pred)}, len(y_true)={len(y_true)}"
            assert len(flatten(y_pred))==len(flatten(y_true)), f"len(flatten(y_pred))={flatten(y_pred)}, len(flatten(y_true))={flatten(y_true)}"

    print(classification_report(flatten(y_true), flatten(y_pred), target_names=list(hp.tag2idx.keys())[1:]))
    
    final_report = classification_report(flatten(y_true), flatten(y_pred), target_names=list(hp.tag2idx.keys())[1:],output_dict=True)

    return final_report["weighted avg"]['precision'], final_report["weighted avg"]['recall'], final_report["weighted avg"]['f1-score']

def save_the_results(model, iterator, f):
    model.eval()

    Words, Is_heads, Tags, Y, Y_hat = [], [], [], [], []
    with torch.no_grad():
        for i, batch in enumerate(iterator):
            words, x, is_heads, tags, y, seqlens = batch

            _, _, y_hat = model(x, y)  # y_hat: (N, T)

            Words.extend(words)
            Is_heads.extend(is_heads)
            Tags.extend(tags)
            Y.extend(y.numpy().tolist())
            Y_hat.extend(y_hat.cpu().numpy().tolist())

    ## gets results and save
    with open(f, 'w') as fout:
        for words, is_heads, tags, y_hat in zip(Words, Is_heads, Tags, Y_hat):
            y_hat = [hat for head, hat in zip(is_heads, y_hat) if head == 1]
            preds = [hp.idx2tag[hat] for hat in y_hat]
            assert len(preds)==len(words.split())==len(tags.split())
            for w, t, p in zip(words.split()[1:-1], tags.split()[1:-1], preds[1:-1]):
                fout.write(f"{w} {t} {p}\n")
            fout.write("\n")

    ## calc metric
    y_true =  np.array([hp.tag2idx[line.split()[1]] for line in open(f, 'r').read().splitlines() if len(line) > 0])
    y_pred =  np.array([hp.tag2idx[line.split()[2]] for line in open(f, 'r').read().splitlines() if len(line) > 0])

    print(classification_report(y_true, y_pred, target_names=list(hp.tag2idx.keys())[1:]))
    
    final_report = classification_report(y_true, y_pred, target_names=list(hp.tag2idx.keys())[1:],output_dict=True)

    final = f + ".P%.2f_R%.2f_F%.2f" %(final_report['weighted avg']['precision'], final_report['weighted avg']['recall'], final_report['weighted avg']['f1-score'])
    with open(final, 'w') as fout:
        result = open(f, "r").read()
        fout.write(f"{result}\n")

        fout.write(f"accuracy={final_report['accuracy']}\n")
        fout.write(f"precision={final_report['weighted avg']['precision']}\n")
        fout.write(f"recall={final_report['weighted avg']['recall']}\n")
        fout.write(f"f1={final_report['weighted avg']['f1-score']}\n")

    os.remove(f)
    return final_report["weighted avg"]['precision'], final_report["weighted avg"]['recall'], final_report["weighted avg"]['f1-score']

# %%
### Combine devel and train file to get more data for training

# Python program to 
# demonstrate merging 
# of two files 
  
train_data = dev_data = "" 
  
# Reading data from file1 
with open("./data/BioNLP13CG-IOB/train.tsv") as fp: 
    train_data = fp.read() 
  
# Reading data from file2 
with open("./data/BioNLP13CG-IOB/devel.tsv") as fp: 
    dev_data = fp.read() 
  
# Merging 2 files 
# To add the data of file2 
# from next line 
#train_data += "\n"
train_data += dev_data 
  
with open ('./data/BioNLP13CG-IOB/train_dev.tsv', 'w') as fp: 
    fp.write(train_data)

# %%
train_dataset = NerDataset("./data/BioNLP13CG-IOB/train_dev.tsv", 'bionlp3g')  # here bc5cdr is dataset type
eval_dataset = NerDataset("./data/BioNLP13CG-IOB/test.tsv", 'bionlp3g')
hp = HParams('bionlp3g')

# Define model 
#config = BertConfig(vocab_size_or_config_json_file=BERT_CONFIG_FILE)
model = Net(vocab_len = len(hp.VOCAB), device=hp.device)
if torch.cuda.is_available():
    model.cuda()
model.train()
# update with already pretrained weight


    
train_iter = data.DataLoader(dataset=train_dataset,
                            batch_size=hp.batch_size,
                            shuffle=True,
                            num_workers=4,
                            collate_fn=pad)
eval_iter = data.DataLoader(dataset=eval_dataset,
                            batch_size=hp.batch_size,
                            shuffle=False,
                            num_workers=4,
                            collate_fn=pad)

optimizer = optim.Adam(model.parameters(), lr = hp.lr)
# optimizer = optim.SGD(model.parameters(), lr=0.0001, momentum=0.9)
criterion = nn.CrossEntropyLoss(ignore_index=0)

for epoch in range(1, hp.n_epochs+1):
    train(model, train_iter, optimizer, criterion)
    print(f"=========eval at epoch={epoch}=========")
    if not os.path.exists('checkpoints_bionlp3g'): os.makedirs('checkpoints_bionlp3g')
    fname = os.path.join('checkpoints_bionlp3g', str(epoch))
    precision, recall, f1 = eval(model, eval_iter, fname)
    torch.save(model.state_dict(), f"{fname}.pt")
# Out:
# =====sanity check======
# words: [CLS] Here we show that heterozygous disruption of beclin 1 increases the frequency of spontaneous malignancies and accelerates the development of hepatitis B virus - induced premalignant lesions . [SEP]
#
#
# tags: <PAD> O O O O O O O B-Gene_or_gene_product I-Gene_or_gene_product O O O O O B-Cancer O O O O O B-Organism I-Organism I-Organism O O B-Pathological_formation I-Pathological_formation O <PAD>
#
#
# step: 0, loss: 3.5409724712371826
# step: 10, loss: 2.25964617729187
# step: 20, loss: 1.4204328060150146
# step: 30, loss: 1.1620620489120483
# =========eval at epoch=1=========
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.00      0.00      0.00       924
#                            B-Cell       0.00      0.00      0.00      1013
#              B-Cellular_component       0.00      0.00      0.00       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.00      0.00      0.00      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.00      0.00      0.00       303
#                           B-Organ       0.00      0.00      0.00       156
#                        B-Organism       0.00      0.00      0.00       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.00      0.00      0.00       727
#                          B-Tissue       0.00      0.00      0.00       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.00      0.00      0.00       604
#                            I-Cell       0.00      0.00      0.00      1091
#              I-Cellular_component       0.00      0.00      0.00        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.00      0.00      0.00      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.00      0.00      0.00       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.00      0.00      0.00       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.00      0.00      0.00       622
#                          I-Tissue       0.00      0.00      0.00       111
#                                 O       0.77      1.00      0.87     40642
#
#                          accuracy                           0.77     52771
#                         macro avg       0.02      0.03      0.03     52771
#                      weighted avg       0.59      0.77      0.67     52771
#
# =====sanity check======
# words: [CLS] Subsequently this activity was separated into TGFbeta and TGFalpha an EGF receptor ligand . [SEP]
#
#
# tags: <PAD> O O O O O O B-Gene_or_gene_product O B-Gene_or_gene_product O B-Gene_or_gene_product O O O <PAD>
#
#
# step: 0, loss: 1.1755053997039795
# step: 10, loss: 1.1081938743591309
# step: 20, loss: 1.0806682109832764
# step: 30, loss: 1.0602478981018066
# =========eval at epoch=2=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.00      0.00      0.00       924
#                            B-Cell       0.00      0.00      0.00      1013
#              B-Cellular_component       0.00      0.00      0.00       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.00      0.00      0.00      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.00      0.00      0.00       303
#                           B-Organ       0.00      0.00      0.00       156
#                        B-Organism       0.00      0.00      0.00       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.00      0.00      0.00       727
#                          B-Tissue       0.00      0.00      0.00       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.00      0.00      0.00       604
#                            I-Cell       0.00      0.00      0.00      1091
#              I-Cellular_component       0.00      0.00      0.00        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.00      0.00      0.00      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.00      0.00      0.00       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.00      0.00      0.00       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.00      0.00      0.00       622
#                          I-Tissue       0.00      0.00      0.00       111
#                                 O       0.77      1.00      0.87     40642
#
#                          accuracy                           0.77     52771
#                         macro avg       0.02      0.03      0.03     52771
#                      weighted avg       0.59      0.77      0.67     52771
#
# =====sanity check======
# words: [CLS] Growth through the foveal center still can occur , however , and this can be associated with substantial visual loss . [SEP]
#
#
# tags: <PAD> O O O B-Tissue I-Tissue O O O O O O O O O O O O O O O O <PAD>
#
#
# step: 0, loss: 1.108166217803955
# step: 10, loss: 0.9767906665802002
# step: 20, loss: 0.9392696619033813
# step: 30, loss: 0.8553489446640015
# =========eval at epoch=3=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.00      0.00      0.00       924
#                            B-Cell       0.00      0.00      0.00      1013
#              B-Cellular_component       0.00      0.00      0.00       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.00      0.00      0.00      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.00      0.00      0.00       303
#                           B-Organ       0.00      0.00      0.00       156
#                        B-Organism       0.00      0.00      0.00       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.00      0.00      0.00       727
#                          B-Tissue       0.00      0.00      0.00       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.00      0.00      0.00       604
#                            I-Cell       0.00      0.00      0.00      1091
#              I-Cellular_component       0.00      0.00      0.00        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.59      0.40      0.47      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.00      0.00      0.00       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.00      0.00      0.00       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.00      0.00      0.00       622
#                          I-Tissue       0.00      0.00      0.00       111
#                                 O       0.79      1.00      0.88     40642
#
#                          accuracy                           0.78     52771
#                         macro avg       0.04      0.04      0.04     52771
#                      weighted avg       0.64      0.78      0.70     52771
#
# =====sanity check======
# words: [CLS] RESULTS : EPOX induced endothelial cell apoptosis in association with proteasome - dependent Mcl - 1 degradation . [SEP]
#
#
# tags: <PAD> O O B-Simple_chemical O B-Cell I-Cell O O O O O O O B-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product O O <PAD>
#
#
# step: 0, loss: 0.8421041965484619
# step: 10, loss: 0.8786736726760864
# step: 20, loss: 0.7429372668266296
# step: 30, loss: 0.6739751100540161
# =========eval at epoch=4=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.00      0.00      0.00       924
#                            B-Cell       0.29      0.00      0.00      1013
#              B-Cellular_component       0.00      0.00      0.00       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.84      0.32      0.46      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.00      0.00      0.00       303
#                           B-Organ       0.00      0.00      0.00       156
#                        B-Organism       0.00      0.00      0.00       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.00      0.00      0.00       727
#                          B-Tissue       0.00      0.00      0.00       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.00      0.00      0.00       604
#                            I-Cell       0.49      0.34      0.40      1091
#              I-Cellular_component       0.00      0.00      0.00        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.62      0.80      0.70      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.00      0.00      0.00       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.00      0.00      0.00       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       1.00      0.00      0.01       622
#                          I-Tissue       0.00      0.00      0.00       111
#                                 O       0.84      0.99      0.91     40642
#
#                          accuracy                           0.82     52771
#                         macro avg       0.12      0.07      0.08     52771
#                      weighted avg       0.74      0.82      0.76     52771
#
# =====sanity check======
# words: [CLS] Ha - ras cells also show less binding of phorbol ester than control cells , suggesting that elevation of DG causes partial down - regulation in addition to activation of protein kinase C . [SEP]
#
#
# tags: <PAD> B-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product O O O O O O B-Simple_chemical I-Simple_chemical O O B-Cell O O O O O B-Simple_chemical O O O O O O O O O O B-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product O <PAD>
#
#
# step: 0, loss: 0.7023285627365112
# step: 10, loss: 0.652842104434967
# step: 20, loss: 0.5121245384216309
# step: 30, loss: 0.5528178811073303
# =========eval at epoch=5=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.76      0.07      0.14       924
#                            B-Cell       0.52      0.39      0.45      1013
#              B-Cellular_component       0.00      0.00      0.00       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.81      0.80      0.81      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.00      0.00      0.00       303
#                           B-Organ       0.00      0.00      0.00       156
#                        B-Organism       0.00      0.00      0.00       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.88      0.04      0.08       727
#                          B-Tissue       0.00      0.00      0.00       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.00      0.00      0.00       604
#                            I-Cell       0.52      0.73      0.61      1091
#              I-Cellular_component       0.00      0.00      0.00        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.82      0.84      0.83      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.00      0.00      0.00       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.00      0.00      0.00       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.82      0.59      0.68       622
#                          I-Tissue       0.00      0.00      0.00       111
#                                 O       0.89      0.99      0.94     40642
#
#                          accuracy                           0.87     52771
#                         macro avg       0.18      0.13      0.14     52771
#                      weighted avg       0.82      0.87      0.83     52771
#
# =====sanity check======
# words: [CLS] Consistent with the decrease in lymph node metastasis , tumor lymphangiogenesis and expression of vascular endothelial growth factor C ( VEGF - C ) was significantly decreased in artemisinin - treated mice , as compared to control mice . [SEP]
#
#
# tags: <PAD> O O O O O B-Multi-tissue_structure I-Multi-tissue_structure O O B-Cancer O O O O B-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product O B-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product O O O O O B-Simple_chemical O O B-Organism O O O O O B-Organism O <PAD>
#
#
# step: 0, loss: 0.5173296332359314
# step: 10, loss: 0.4847579896450043
# step: 20, loss: 0.4554828107357025
# step: 30, loss: 0.4137595295906067
# =========eval at epoch=6=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.62      0.55      0.58       924
#                            B-Cell       0.60      0.61      0.61      1013
#              B-Cellular_component       0.00      0.00      0.00       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.85      0.87      0.86      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.00      0.00      0.00       303
#                           B-Organ       0.00      0.00      0.00       156
#                        B-Organism       0.00      0.00      0.00       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.78      0.39      0.52       727
#                          B-Tissue       0.00      0.00      0.00       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.76      0.54      0.63       604
#                            I-Cell       0.70      0.81      0.75      1091
#              I-Cellular_component       0.00      0.00      0.00        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.85      0.88      0.86      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.00      0.00      0.00       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.00      0.00      0.00       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.77      0.73      0.75       622
#                          I-Tissue       0.00      0.00      0.00       111
#                                 O       0.93      0.99      0.96     40642
#
#                          accuracy                           0.90     52771
#                         macro avg       0.21      0.19      0.20     52771
#                      weighted avg       0.86      0.90      0.88     52771
#
# =====sanity check======
# words: [CLS] In addition , all of the endometrial cancer cell lines lost normal DCC expression . [SEP]
#
#
# tags: <PAD> O O O O O O B-Cell I-Cell I-Cell I-Cell O O B-Gene_or_gene_product O O <PAD>
#
#
# step: 0, loss: 0.41278091073036194
# step: 10, loss: 0.4060373902320862
# step: 20, loss: 0.3733939826488495
# step: 30, loss: 0.3781028389930725
# =========eval at epoch=7=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.62      0.67      0.64       924
#                            B-Cell       0.58      0.77      0.66      1013
#              B-Cellular_component       0.00      0.00      0.00       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.87      0.88      0.87      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.25      0.00      0.01       303
#                           B-Organ       0.00      0.00      0.00       156
#                        B-Organism       0.00      0.00      0.00       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.77      0.57      0.66       727
#                          B-Tissue       0.00      0.00      0.00       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.73      0.65      0.68       604
#                            I-Cell       0.73      0.84      0.78      1091
#              I-Cellular_component       0.00      0.00      0.00        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.89      0.87      0.88      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.00      0.00      0.00       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.00      0.00      0.00       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.87      0.71      0.78       622
#                          I-Tissue       0.00      0.00      0.00       111
#                                 O       0.94      0.99      0.96     40642
#
#                          accuracy                           0.91     52771
#                         macro avg       0.22      0.21      0.21     52771
#                      weighted avg       0.87      0.91      0.89     52771
#
# =====sanity check======
# words: [CLS] This action is not observed with uninfected CEF , and , therefore , appears to require some expression of the viral src gene in the target cells . [SEP]
#
#
# tags: <PAD> O O O O O O O B-Cell O O O O O O O O O O O O O B-Gene_or_gene_product O O O O B-Cell O <PAD>
#
#
# step: 0, loss: 0.32574957609176636
# step: 10, loss: 0.34656649827957153
# step: 20, loss: 0.34864214062690735
# step: 30, loss: 0.29843392968177795
# =========eval at epoch=8=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.62      0.77      0.69       924
#                            B-Cell       0.67      0.76      0.72      1013
#              B-Cellular_component       0.00      0.00      0.00       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.85      0.91      0.88      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.46      0.10      0.16       303
#                           B-Organ       0.00      0.00      0.00       156
#                        B-Organism       0.57      0.04      0.08       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.84      0.53      0.65       727
#                          B-Tissue       0.00      0.00      0.00       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.70      0.73      0.72       604
#                            I-Cell       0.81      0.82      0.82      1091
#              I-Cellular_component       0.00      0.00      0.00        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.90      0.87      0.88      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.40      0.04      0.07       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       1.00      0.04      0.08       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.90      0.71      0.79       622
#                          I-Tissue       0.00      0.00      0.00       111
#                                 O       0.94      0.99      0.97     40642
#
#                          accuracy                           0.91     52771
#                         macro avg       0.29      0.22      0.23     52771
#                      weighted avg       0.89      0.91      0.90     52771
#
# =====sanity check======
# words: [CLS] After staining samples for alpha - SMA , their expression was extracted and quantified as a relative percentage by computer - assisted image analysis . [SEP]
#
#
# tags: <PAD> O O O O B-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product O O O O O O O O O O O O O O O O O O <PAD>
#
#
# step: 0, loss: 0.3065486252307892
# step: 10, loss: 0.3190065920352936
# step: 20, loss: 0.30371829867362976
# step: 30, loss: 0.2957199513912201
# =========eval at epoch=9=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.67      0.79      0.72       924
#                            B-Cell       0.63      0.84      0.72      1013
#              B-Cellular_component       1.00      0.02      0.03       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.85      0.91      0.88      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.42      0.42      0.42       303
#                           B-Organ       0.00      0.00      0.00       156
#                        B-Organism       0.67      0.18      0.29       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.76      0.70      0.73       727
#                          B-Tissue       0.00      0.00      0.00       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.77      0.75      0.76       604
#                            I-Cell       0.77      0.86      0.81      1091
#              I-Cellular_component       0.00      0.00      0.00        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.87      0.90      0.88      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.48      0.36      0.41       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.92      0.20      0.33       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.88      0.76      0.81       622
#                          I-Tissue       0.00      0.00      0.00       111
#                                 O       0.96      0.98      0.97     40642
#
#                          accuracy                           0.92     52771
#                         macro avg       0.32      0.26      0.27     52771
#                      weighted avg       0.90      0.92      0.91     52771
#
# =====sanity check======
# words: [CLS] Acquired molecular abnormalities ( mutations or chromosomal translocations ) of the RUNX1 transcription factor gene are frequent in acute myeloblastic leukemias ( AMLs ) and in therapy - related myelodysplastic syndromes , but rarely in acute lymphoblastic leukemias ( ALLs ) and chronic myelogenous leukemias ( CMLs ) . [SEP]
#
#
# tags: <PAD> O O O O O O B-Cellular_component O O O O B-Gene_or_gene_product O O O O O O B-Cancer I-Cancer I-Cancer O B-Cancer O O O O O O O O O O O O B-Cancer I-Cancer I-Cancer O B-Cancer O O B-Cancer I-Cancer I-Cancer O B-Cancer O O <PAD>
#
#
# step: 0, loss: 0.2735045254230499
# step: 10, loss: 0.28628310561180115
# step: 20, loss: 0.25949764251708984
# step: 30, loss: 0.23347090184688568
# =========eval at epoch=10=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.74      0.81      0.77       924
#                            B-Cell       0.74      0.81      0.77      1013
#              B-Cellular_component       0.92      0.06      0.11       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.84      0.92      0.88      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.51      0.43      0.46       303
#                           B-Organ       0.00      0.00      0.00       156
#                        B-Organism       0.67      0.29      0.40       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.87      0.57      0.69       727
#                          B-Tissue       0.32      0.03      0.06       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.82      0.76      0.79       604
#                            I-Cell       0.84      0.84      0.84      1091
#              I-Cellular_component       0.00      0.00      0.00        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.88      0.90      0.89      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.57      0.45      0.51       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.88      0.29      0.44       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.91      0.74      0.82       622
#                          I-Tissue       0.00      0.00      0.00       111
#                                 O       0.95      0.99      0.97     40642
#
#                          accuracy                           0.93     52771
#                         macro avg       0.35      0.27      0.28     52771
#                      weighted avg       0.91      0.93      0.91     52771
#
# =====sanity check======
# words: [CLS] In a three - dimensional model of breast carcinogenesis , disorganized , proliferative transformed breast epithelial cells express significantly higher expression of angiogenic genes compared with their polarized , growth - arrested nonmalignant counterparts . [SEP]
#
#
# tags: <PAD> O O O O O O O B-Organism_subdivision O O O O O O B-Cell I-Cell I-Cell O O O O O O O O O O O O O O O B-Cell I-Cell O <PAD>
#
#
# step: 0, loss: 0.22910238802433014
# step: 10, loss: 0.23807229101657867
# step: 20, loss: 0.2581683397293091
# step: 30, loss: 0.24108970165252686
# =========eval at epoch=11=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.71      0.83      0.77       924
#                            B-Cell       0.76      0.82      0.79      1013
#              B-Cellular_component       0.88      0.12      0.21       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.89      0.88      0.89      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.48      0.55      0.51       303
#                           B-Organ       1.00      0.01      0.01       156
#                        B-Organism       0.73      0.35      0.47       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.71      0.78      0.74       727
#                          B-Tissue       0.19      0.02      0.04       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.77      0.81      0.79       604
#                            I-Cell       0.84      0.85      0.84      1091
#              I-Cellular_component       0.00      0.00      0.00        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.90      0.89      0.90      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.54      0.64      0.58       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.82      0.34      0.48       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.84      0.79      0.82       622
#                          I-Tissue       0.50      0.01      0.02       111
#                                 O       0.96      0.99      0.97     40642
#
#                          accuracy                           0.93     52771
#                         macro avg       0.38      0.29      0.30     52771
#                      weighted avg       0.92      0.93      0.92     52771
#
# =====sanity check======
# words: [CLS] The pharmacokinetics of STX243 were examined at two different doses using adult female rats . [SEP]
#
#
# tags: <PAD> O O O B-Simple_chemical O O O O O O O O O B-Organism O <PAD>
#
#
# step: 0, loss: 0.21721291542053223
# step: 10, loss: 0.23795799911022186
# step: 20, loss: 0.24661490321159363
# step: 30, loss: 0.24113807082176208
# =========eval at epoch=12=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.69      0.88      0.77       924
#                            B-Cell       0.81      0.80      0.81      1013
#              B-Cellular_component       0.67      0.22      0.33       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.85      0.92      0.88      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.44      0.66      0.53       303
#                           B-Organ       0.75      0.02      0.04       156
#                        B-Organism       0.69      0.58      0.63       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.81      0.73      0.77       727
#                          B-Tissue       0.31      0.05      0.08       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.81      0.82      0.81       604
#                            I-Cell       0.84      0.85      0.84      1091
#              I-Cellular_component       0.71      0.07      0.13        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.84      0.92      0.88      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.49      0.75      0.59       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.77      0.39      0.52       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.90      0.78      0.83       622
#                          I-Tissue       0.50      0.01      0.02       111
#                                 O       0.97      0.98      0.98     40642
#
#                          accuracy                           0.93     52771
#                         macro avg       0.39      0.32      0.32     52771
#                      weighted avg       0.92      0.93      0.92     52771
#
# =====sanity check======
# words: [CLS] In addition , these clones also exhibit aggressive tumorigenic phenotypes in vivo with short latency in tumor formation in both immunodeficient and syngeneic mice . [SEP]
#
#
# tags: <PAD> O O O O B-Cell O O O O O O O O O O O B-Cancer O O O B-Organism O B-Organism I-Organism O <PAD>
#
#
# step: 0, loss: 0.2105928510427475
# step: 10, loss: 0.24826499819755554
# step: 20, loss: 0.19077900052070618
# step: 30, loss: 0.19569000601768494
# =========eval at epoch=13=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.78      0.82      0.80       924
#                            B-Cell       0.75      0.85      0.80      1013
#              B-Cellular_component       0.67      0.33      0.45       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.86      0.92      0.89      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.49      0.62      0.54       303
#                           B-Organ       0.88      0.04      0.09       156
#                        B-Organism       0.71      0.66      0.68       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.80      0.73      0.77       727
#                          B-Tissue       0.45      0.09      0.15       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.81      0.81      0.81       604
#                            I-Cell       0.84      0.85      0.85      1091
#              I-Cellular_component       0.90      0.13      0.23        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.87      0.92      0.89      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.58      0.72      0.64       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.75      0.42      0.54       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.87      0.80      0.83       622
#                          I-Tissue       0.71      0.05      0.08       111
#                                 O       0.97      0.98      0.98     40642
#
#                          accuracy                           0.93     52771
#                         macro avg       0.42      0.33      0.33     52771
#                      weighted avg       0.92      0.93      0.93     52771
#
# =====sanity check======
# words: [CLS] A novel putative tyrosine kinase receptor with oncogenic potential . [SEP]
#
#
# tags: <PAD> O O O B-Amino_acid O O O O O O <PAD>
#
#
# step: 0, loss: 0.1890610307455063
# step: 10, loss: 0.17071351408958435
# step: 20, loss: 0.21938440203666687
# step: 30, loss: 0.1963457465171814
# =========eval at epoch=14=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.79      0.84      0.81       924
#                            B-Cell       0.82      0.83      0.82      1013
#              B-Cellular_component       0.68      0.32      0.43       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.89      0.90      0.90      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.50      0.61      0.55       303
#                           B-Organ       0.68      0.11      0.19       156
#                        B-Organism       0.74      0.66      0.70       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.00      0.00      0.00       102
#          B-Pathological_formation       0.00      0.00      0.00        88
#                 B-Simple_chemical       0.78      0.76      0.77       727
#                          B-Tissue       0.47      0.09      0.15       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.83      0.83      0.83       604
#                            I-Cell       0.88      0.85      0.86      1091
#              I-Cellular_component       0.79      0.22      0.34        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.90      0.90      0.90      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.61      0.72      0.66       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.76      0.46      0.57       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.80      0.84      0.82       622
#                          I-Tissue       0.67      0.13      0.21       111
#                                 O       0.97      0.99      0.98     40642
#
#                          accuracy                           0.94     52771
#                         macro avg       0.41      0.33      0.35     52771
#                      weighted avg       0.93      0.94      0.93     52771
#
# =====sanity check======
# words: [CLS] In vivo p53 response and immune reaction underlie highly effective low - dose radiotherapy in follicular lymphoma . [SEP]
#
#
# tags: <PAD> O O B-Gene_or_gene_product O O O O O O O O O O O O B-Cancer I-Cancer O <PAD>
#
#
# step: 0, loss: 0.16913636028766632
# step: 10, loss: 0.21467788517475128
# step: 20, loss: 0.18956448137760162
# step: 30, loss: 0.1977737545967102
# =========eval at epoch=15=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       0.00      0.00      0.00        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.77      0.87      0.81       924
#                            B-Cell       0.82      0.84      0.83      1013
#              B-Cellular_component       0.63      0.40      0.49       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.87      0.93      0.90      2520
#    B-Immaterial_anatomical_entity       0.00      0.00      0.00        31
#          B-Multi-tissue_structure       0.51      0.65      0.57       303
#                           B-Organ       0.56      0.13      0.21       156
#                        B-Organism       0.76      0.69      0.72       518
# ...
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.90      0.91      0.91      2520
#    B-Immaterial_anatomical_entity       1.00      0.10      0.18        31
#          B-Multi-tissue_structure       0.59      0.66      0.62       303
#                           B-Organ       0.56      0.48      0.52       156
#                        B-Organism       0.83      0.82      0.83       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.72      0.21      0.32       102
#          B-Pathological_formation       0.67      0.02      0.04        88
#                 B-Simple_chemical       0.76      0.82      0.79       727
#                          B-Tissue       0.50      0.50      0.50       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.85      0.85      0.85       604
#                            I-Cell       0.92      0.84      0.88      1091
#              I-Cellular_component       0.79      0.45      0.57        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.93      0.89      0.91      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.69      0.78      0.73       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.88      0.50      0.64       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.00      0.00      0.00        39
#                 I-Simple_chemical       0.84      0.81      0.82       622
#                          I-Tissue       0.63      0.46      0.53       111
#                                 O       0.97      0.99      0.98     40642
#
#                          accuracy                           0.95     52771
#                         macro avg       0.53      0.40      0.42     52771
#                      weighted avg       0.94      0.95      0.94     52771
#
# =====sanity check======
# words: [CLS] Additionally , cediranib blocked VEGF - C156S - induced and VEGF - E - induced proliferation , survival , and migration of lymphatic and blood vascular endothelial cells . [SEP]
#
#
# tags: <PAD> O O B-Simple_chemical O B-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product O O O B-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product O O O O O O O O O B-Cell O B-Cell I-Cell I-Cell I-Cell O <PAD>
#
#
# step: 0, loss: 0.10799890756607056
# step: 10, loss: 0.11286333203315735
# step: 20, loss: 0.0934751033782959
# step: 30, loss: 0.10661331564188004
# =========eval at epoch=27=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       1.00      0.03      0.06        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.81      0.88      0.85       924
#                            B-Cell       0.85      0.86      0.85      1013
#              B-Cellular_component       0.72      0.47      0.57       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.87      0.93      0.90      2520
#    B-Immaterial_anatomical_entity       0.75      0.10      0.17        31
#          B-Multi-tissue_structure       0.56      0.72      0.63       303
#                           B-Organ       0.57      0.36      0.44       156
#                        B-Organism       0.81      0.84      0.83       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.66      0.19      0.29       102
#          B-Pathological_formation       0.33      0.02      0.04        88
#                 B-Simple_chemical       0.82      0.76      0.79       727
#                          B-Tissue       0.55      0.33      0.41       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.83      0.86      0.85       604
#                            I-Cell       0.90      0.86      0.88      1091
#              I-Cellular_component       0.80      0.51      0.62        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.91      0.91      0.91      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.65      0.81      0.72       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.87      0.52      0.65       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       1.00      0.03      0.05        39
#                 I-Simple_chemical       0.89      0.79      0.84       622
#                          I-Tissue       0.70      0.39      0.50       111
#                                 O       0.97      0.99      0.98     40642
#
#                          accuracy                           0.95     52771
#                         macro avg       0.54      0.40      0.42     52771
#                      weighted avg       0.94      0.95      0.94     52771
#
# =====sanity check======
# words: [CLS] TES2 mediates the interaction with tumor necrosis factor receptor - associated death domain protein ( TRADD ) and plays a key role in transactivating NF - kappa B and AP - 1 . [SEP]
#
#
# tags: <PAD> O O O O O B-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product O O B-Gene_or_gene_product O O O O O O O O B-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product O B-Gene_or_gene_product I-Gene_or_gene_product I-Gene_or_gene_product O <PAD>
#
#
# step: 0, loss: 0.10999502241611481
# step: 10, loss: 0.08015536516904831
# step: 20, loss: 0.10357442498207092
# step: 30, loss: 0.11585725843906403
# =========eval at epoch=28=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       1.00      0.02      0.03        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.86      0.86      0.86       924
#                            B-Cell       0.86      0.85      0.86      1013
#              B-Cellular_component       0.71      0.52      0.60       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.89      0.93      0.91      2520
#    B-Immaterial_anatomical_entity       0.75      0.10      0.17        31
#          B-Multi-tissue_structure       0.63      0.65      0.64       303
#                           B-Organ       0.58      0.40      0.47       156
#                        B-Organism       0.81      0.86      0.83       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.64      0.23      0.33       102
#          B-Pathological_formation       0.40      0.07      0.12        88
#                 B-Simple_chemical       0.83      0.72      0.78       727
#                          B-Tissue       0.55      0.47      0.51       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.87      0.82      0.85       604
#                            I-Cell       0.94      0.83      0.88      1091
#              I-Cellular_component       0.78      0.42      0.55        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.93      0.88      0.91      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.77      0.72      0.75       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.88      0.42      0.56       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       1.00      0.03      0.05        39
#                 I-Simple_chemical       0.94      0.73      0.82       622
#                          I-Tissue       0.73      0.42      0.54       111
#                                 O       0.97      0.99      0.98     40642
#
#                          accuracy                           0.95     52771
#                         macro avg       0.56      0.39      0.42     52771
#                      weighted avg       0.94      0.95      0.94     52771
#
# =====sanity check======
# words: [CLS] Visual acuity in eyes with progressive lesions decreased a median of 4 lines of vision . [SEP]
#
#
# tags: <PAD> O O O B-Organ O O B-Pathological_formation O O O O O O O O O <PAD>
#
#
# step: 0, loss: 0.09438782185316086
# step: 10, loss: 0.11950951814651489
# step: 20, loss: 0.09653942286968231
# step: 30, loss: 0.08931443840265274
# =========eval at epoch=29=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       1.00      0.06      0.12        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.84      0.86      0.85       924
#                            B-Cell       0.83      0.87      0.85      1013
#              B-Cellular_component       0.71      0.51      0.60       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.89      0.92      0.91      2520
#    B-Immaterial_anatomical_entity       0.38      0.10      0.15        31
#          B-Multi-tissue_structure       0.61      0.69      0.65       303
#                           B-Organ       0.54      0.44      0.49       156
#                        B-Organism       0.83      0.84      0.83       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.57      0.27      0.37       102
#          B-Pathological_formation       0.40      0.02      0.04        88
#                 B-Simple_chemical       0.81      0.77      0.79       727
#                          B-Tissue       0.48      0.54      0.51       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.82      0.86      0.84       604
#                            I-Cell       0.90      0.87      0.88      1091
#              I-Cellular_component       0.77      0.48      0.59        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.91      0.91      0.91      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.72      0.80      0.76       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.87      0.52      0.65       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.50      0.05      0.09        39
#                 I-Simple_chemical       0.90      0.80      0.84       622
#                          I-Tissue       0.63      0.47      0.54       111
#                                 O       0.98      0.99      0.98     40642
#
#                          accuracy                           0.95     52771
#                         macro avg       0.51      0.41      0.43     52771
#                      weighted avg       0.94      0.95      0.94     52771
#
# =====sanity check======
# words: [CLS] The effect of taxol , cobalt chloride and a heparin - steroid combination was tested in the fat tissue assay and compared to the validated human placental vein angiogenesis model ( HPVAM ) . [SEP]
#
#
# tags: <PAD> O O O B-Simple_chemical O B-Simple_chemical I-Simple_chemical O O B-Simple_chemical I-Simple_chemical I-Simple_chemical O O O O O B-Tissue I-Tissue O O O O O O B-Organism B-Multi-tissue_structure I-Multi-tissue_structure O O O O O O <PAD>
#
#
# step: 0, loss: 0.08932449668645859
# step: 10, loss: 0.08467710763216019
# step: 20, loss: 0.07537563145160675
# step: 30, loss: 0.0999777764081955
# =========eval at epoch=30=========
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       1.00      0.06      0.12        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.84      0.86      0.85       924
#                            B-Cell       0.84      0.86      0.85      1013
#              B-Cellular_component       0.74      0.48      0.58       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.88      0.93      0.90      2520
#    B-Immaterial_anatomical_entity       0.67      0.13      0.22        31
#          B-Multi-tissue_structure       0.58      0.72      0.64       303
#                           B-Organ       0.65      0.35      0.46       156
#                        B-Organism       0.83      0.82      0.83       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.63      0.26      0.37       102
#          B-Pathological_formation       0.67      0.16      0.26        88
#                 B-Simple_chemical       0.82      0.76      0.79       727
#                          B-Tissue       0.56      0.49      0.52       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.83      0.85      0.84       604
#                            I-Cell       0.89      0.88      0.89      1091
#              I-Cellular_component       0.80      0.51      0.62        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.88      0.92      0.90      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.71      0.79      0.75       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.85      0.53      0.66       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.67      0.05      0.10        39
#                 I-Simple_chemical       0.90      0.79      0.84       622
#                          I-Tissue       0.62      0.52      0.57       111
#                                 O       0.98      0.99      0.98     40642
#
#                          accuracy                           0.95     52771
#                         macro avg       0.54      0.42      0.44     52771
#                      weighted avg       0.94      0.95      0.94     52771

# %% [markdown]
# *Final accuracy produced is 95%. This is pretty good considering there was not enough training data for several entities.*

# %% [markdown]
# #### Run the final model and save the output

# %%
eval_dataset = NerDataset("./data/BioNLP13CG-IOB/test.tsv", 'bionlp3g')
hp = HParams('bionlp3g')

eval_iter = data.DataLoader(dataset=eval_dataset,
                            batch_size=hp.batch_size,
                            shuffle=False,
                            num_workers=4,
                            collate_fn=pad)


model = Net(vocab_len = len(hp.VOCAB), device=hp.device)
model.load_state_dict(torch.load("./checkpoints_bionlp3g/30.pt"))
model.eval()
# Out:
# Net(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (rnn): LSTM(768, 384, num_layers=2, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=768, out_features=34, bias=True)
# )

# %%
precision, recall, f1 = save_the_results(model, eval_iter, "./checkpoints_bionlp3g/final_results")
# Out:
#                                    precision    recall  f1-score   support
#
#                      B-Amino_acid       1.00      0.06      0.12        62
#               B-Anatomical_system       0.00      0.00      0.00        17
#                          B-Cancer       0.84      0.86      0.85       924
#                            B-Cell       0.84      0.86      0.85      1013
#              B-Cellular_component       0.74      0.48      0.58       180
# B-Developing_anatomical_structure       0.00      0.00      0.00        17
#            B-Gene_or_gene_product       0.88      0.93      0.90      2520
#    B-Immaterial_anatomical_entity       0.67      0.13      0.22        31
#          B-Multi-tissue_structure       0.58      0.72      0.64       303
#                           B-Organ       0.65      0.35      0.46       156
#                        B-Organism       0.83      0.82      0.83       518
#            B-Organism_subdivision       0.00      0.00      0.00        39
#              B-Organism_substance       0.63      0.26      0.37       102
#          B-Pathological_formation       0.67      0.16      0.26        88
#                 B-Simple_chemical       0.82      0.76      0.79       727
#                          B-Tissue       0.56      0.49      0.52       184
#                      I-Amino_acid       0.00      0.00      0.00         3
#               I-Anatomical_system       0.00      0.00      0.00         9
#                          I-Cancer       0.83      0.85      0.84       604
#                            I-Cell       0.89      0.88      0.89      1091
#              I-Cellular_component       0.80      0.51      0.62        69
# I-Developing_anatomical_structure       0.00      0.00      0.00         4
#            I-Gene_or_gene_product       0.88      0.92      0.90      2354
#    I-Immaterial_anatomical_entity       0.00      0.00      0.00        10
#          I-Multi-tissue_structure       0.71      0.79      0.75       162
#                           I-Organ       0.00      0.00      0.00        17
#                        I-Organism       0.85      0.53      0.66       120
#            I-Organism_subdivision       0.00      0.00      0.00         9
#              I-Organism_substance       0.00      0.00      0.00        24
#          I-Pathological_formation       0.67      0.05      0.10        39
#                 I-Simple_chemical       0.90      0.79      0.84       622
#                          I-Tissue       0.62      0.52      0.57       111
#                                 O       0.98      0.99      0.98     40642
#
#                          accuracy                           0.95     52771
#                         macro avg       0.54      0.42      0.44     52771
#                      weighted avg       0.94      0.95      0.94     52771
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
